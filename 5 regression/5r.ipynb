# %%
import numpy as np
from scipy.io import arff
from io import StringIO
import sklearn
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn import preprocessing
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LinearRegression
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.exceptions import ConvergenceWarning
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)
warnings.filterwarnings("ignore", category=FutureWarning) 
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=ConvergenceWarning)
from sklearn.metrics import mean_squared_error
import pandas as pd

# %%
def read(a):
    b = pd.read_csv(a, delimiter = ';')
    le = preprocessing.LabelEncoder()
    b['Type'] = le.fit_transform(b['Type'])
    b = b.astype(np.float64)
    return b.to_numpy()

# %%
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        j = 0
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")
            if j > 1:
                break
            j+=1



def randomCV(clf, X, y, param_grid, n_iter, cv):
    random_search = RandomizedSearchCV(clf, param_distributions = param_grid,
          n_iter = n_iter, cv = cv, iid = False)
    random_search.fit(X, y)
    report(random_search.cv_results_)
    return random_search.best_params_

def Rf(x, y):
  clf = RandomForestRegressor()
  param_grid = {
        "n_estimators" : np.arange(2,50),
        "max_depth" : np.arange(1,6),

    # "criterion" : ['mse', 'mae'],
    # "min_samples_split" : np.random.random_sample((100,)),      
    # "min_samples_split" : np.linspace(0.01,1, num = 1000),
    # "min_samples_leaf" : np.linspace(0.01,0.5, num = 100),
    # "bootstrap" : [True, False],
    # "warm_start" : [True, False]
  }
  return randomCV(clf, x, y, param_grid, 50, 6)  


def Dt(x, y):
  clf = DecisionTreeRegressor()
  param_grid = {
      "max_depth" : np.arange(1,6),
      "min_samples_split" : np.linspace(0.01,0.5, num = 1000),
      "min_samples_leaf" : np.linspace(0.01,0.5, num = 1000),

      # "criterion" : ['mse', 'mae', 'friedman_mse'],
      # "splitter" : ['best', 'random'],
  }
  return randomCV(clf, x, y, param_grid, 400, 6)  

def Svr(x, y):
  clf = svm.SVR()
  param_grid = {
      "kernel" : ['poly', 'rbf', 'linear', 'sigmoid'],
      "gamma" : ['scale', 'auto'],
      "shrinking" : [True, False]
  }
  return randomCV(clf, x, y, param_grid, 4, 6)

def Ada(x, y):
  clf = AdaBoostRegressor()
  param_grid = {
      "n_estimators" : np.arange(1,100),
      "loss" : ['linear', 'square', 'exponential'],
      # "learning_rate" : np.arange(1,)
  }
  return randomCV(clf, x, y, param_grid, 30, 6)

def GP(x, y):
  clf = GaussianProcessRegressor()
  param_grid = {
#       "kernel" : [RBF, WhiteKernel],
      "normalize_y" : [True, False],
      "copy_X_train" : [True, False],
#       "alpha" : np.linspace(0, 3, 100),
      
  }
  return randomCV(clf, x, y, param_grid, 4, 6)

def LR(x, y):
  clf = LinearRegression()
  param_grid = {
      "fit_intercept" : [True, False],
      "normalize" : [True, False],
      "copy_X" : [True, False],
  }
  return randomCV(clf, x, y, param_grid, 25, 6)

def NN(x, y):
  clf = MLPRegressor()
  param_grid = {
      "hidden_layer_sizes" : np.arange(1,200),
      "activation" : ['identity', 'logistic', 'tanh', 'relu'],
      "solver" : ['lbfgs', 'sgd', 'adam'],
      "learning_rate" : ['constant', 'invscaling', 'adaptive'],
      "shuffle" : [True, False],
      "alpha" : np.random.uniform(0.000001, 1, 1000)
  }
  return randomCV(clf, x, y, param_grid, 30, 6)

# %%
# ---------------> Run for data preprocessing

data = read("5facebook.csv")

np.random.shuffle(data)

y = data[:,-12:]
x = data[:,:6]

x_test, x_train = np.split(x, [75])
y_test, y_train = np.split(y, [75])

scaler = StandardScaler()                         # scaling features
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

scaler.fit(y_train)
y_train_nn = scaler.transform(y_train)
y_test_nn = scaler.transform(y_test)


# print(y_train.shape, x_train.shape)

# np.where(np.isnan(y_train))

# y_train = np.nan_to_num(y_train)

col_mean = np.nanmean(y_train, axis=0)
inds = np.where(np.isnan(y_train))
y_train[inds] = np.take(col_mean, inds[1])

col_mean = np.nanmean(y_test, axis=0)
inds = np.where(np.isnan(y_test))
y_test[inds] = np.take(col_mean, inds[1])

col_mean = np.nanmean(x_train, axis=0)
inds = np.where(np.isnan(x_train))
x_train[inds] = np.take(col_mean, inds[1])

col_mean = np.nanmean(x_test, axis=0)
inds = np.where(np.isnan(x_test))
x_test[inds] = np.take(col_mean, inds[1])

col_mean = np.nanmean(y_train_nn, axis=0)
inds = np.where(np.isnan(y_train_nn))
y_train_nn[inds] = np.take(col_mean, inds[1])

col_mean = np.nanmean(y_test_nn, axis=0)
inds = np.where(np.isnan(y_test_nn))
y_test_nn[inds] = np.take(col_mean, inds[1])

# %%
# ---------------> Run for Decision Tree regresssor
j = 0
for i in y_train.T:
    param = Dt(x_train, i)
    reg_tree = DecisionTreeRegressor().set_params(**param)
    reg_tree.fit(x_train, i)
    prediction = reg_tree.predict(x_test)

    rmse = mean_squared_error(y_test[:,j], prediction)
    print("RMSE on test data : ", rmse)

    print("Score with test data",reg_tree.score(x_test, y_test[:,j]))
    print('new data\n\n\n\n\n\n')
    j+=1
# Out:
# Model with rank: 1
# Mean validation score: 0.017 (std: 0.054)
# Parameters: {'min_samples_split': 0.057577577577577574, 'min_samples_leaf': 0.22189189189189187, 'max_depth': 5}
#
# Model with rank: 1
# Mean validation score: 0.017 (std: 0.054)
# Parameters: {'min_samples_split': 0.08798798798798797, 'min_samples_leaf': 0.22091091091091092, 'max_depth': 3}
#
# Model with rank: 3
# Mean validation score: 0.016 (std: 0.052)
# Parameters: {'min_samples_split': 0.06395395395395395, 'min_samples_leaf': 0.22924924924924925, 'max_depth': 2}
#
# RMSE on test data :  504339950.8519739
# Score with test data 0.06094882390042233
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.002 (std: 0.047)
# Parameters: {'min_samples_split': 0.31214214214214214, 'min_samples_leaf': 0.17186186186186186, 'max_depth': 4}
#
# Model with rank: 2
# Mean validation score: -0.002 (std: 0.049)
# Parameters: {'min_samples_split': 0.23856856856856856, 'min_samples_leaf': 0.17480480480480481, 'max_depth': 4}
#
# Model with rank: 3
# Mean validation score: -0.003 (std: 0.048)
# Parameters: {'min_samples_split': 0.1752952952952953, 'min_samples_leaf': 0.17578578578578577, 'max_depth': 4}
#
# Model with rank: 3
# Mean validation score: -0.003 (std: 0.048)
# Parameters: {'min_samples_split': 0.09534534534534533, 'min_samples_leaf': 0.17823823823823823, 'max_depth': 3}
#
# Model with rank: 3
# Mean validation score: -0.003 (std: 0.048)
# Parameters: {'min_samples_split': 0.3278378378378378, 'min_samples_leaf': 0.1802002002002002, 'max_depth': 3}
#
# RMSE on test data :  4281852575.983378
# Score with test data 0.047744971787189505
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.152 (std: 0.234)
# Parameters: {'min_samples_split': 0.37933933933933933, 'min_samples_leaf': 0.035015015015015014, 'max_depth': 5}
#
# Model with rank: 2
# Mean validation score: 0.149 (std: 0.229)
# Parameters: {'min_samples_split': 0.448988988988989, 'min_samples_leaf': 0.019809809809809807, 'max_depth': 4}
#
# Model with rank: 2
# Mean validation score: 0.149 (std: 0.229)
# Parameters: {'min_samples_split': 0.47596596596596596, 'min_samples_leaf': 0.029129129129129128, 'max_depth': 5}
#
# Model with rank: 2
# Mean validation score: 0.149 (std: 0.229)
# Parameters: {'min_samples_split': 0.49754754754754754, 'min_samples_leaf': 0.055615615615615614, 'max_depth': 5}
#
# RMSE on test data :  251371.5194925277
# Score with test data 0.3223150319656821
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.206 (std: 0.263)
# Parameters: {'min_samples_split': 0.03452452452452452, 'min_samples_leaf': 0.08112112112112112, 'max_depth': 5}
#
# Model with rank: 2
# Mean validation score: 0.203 (std: 0.270)
# Parameters: {'min_samples_split': 0.14047047047047048, 'min_samples_leaf': 0.09338338338338337, 'max_depth': 5}
#
# Model with rank: 3
# Mean validation score: 0.197 (std: 0.270)
# Parameters: {'min_samples_split': 0.15616616616616616, 'min_samples_leaf': 0.016866866866866868, 'max_depth': 5}
#
# RMSE on test data :  185492.70019270663
# Score with test data 0.34843762897916
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.117 (std: 0.090)
# Parameters: {'min_samples_split': 0.12526526526526527, 'min_samples_leaf': 0.035015015015015014, 'max_depth': 3}
#
# Model with rank: 2
# Mean validation score: 0.108 (std: 0.088)
# Parameters: {'min_samples_split': 0.037957957957957957, 'min_samples_leaf': 0.033053053053053054, 'max_depth': 3}
#
# Model with rank: 3
# Mean validation score: 0.108 (std: 0.087)
# Parameters: {'min_samples_split': 0.039429429429429425, 'min_samples_leaf': 0.037467467467467465, 'max_depth': 3}
#
# Model with rank: 3
# Mean validation score: 0.108 (std: 0.087)
# Parameters: {'min_samples_split': 0.08308308308308307, 'min_samples_leaf': 0.02961961961961962, 'max_depth': 3}
#
# RMSE on test data :  1173169.1146932277
# Score with test data 0.2577142865821771
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.080 (std: 0.150)
# Parameters: {'min_samples_split': 0.12526526526526527, 'min_samples_leaf': 0.5, 'max_depth': 5}
#
# Model with rank: 2
# Mean validation score: -0.133 (std: 0.271)
# Parameters: {'min_samples_split': 0.20766766766766767, 'min_samples_leaf': 0.4950950950950951, 'max_depth': 5}
#
# Model with rank: 3
# Mean validation score: -0.133 (std: 0.271)
# Parameters: {'min_samples_split': 0.4215215215215215, 'min_samples_leaf': 0.4887187187187187, 'max_depth': 4}
#
# Model with rank: 3
# Mean validation score: -0.133 (std: 0.271)
# Parameters: {'min_samples_split': 0.20913913913913915, 'min_samples_leaf': 0.4941141141141141, 'max_depth': 3}
#
# Model with rank: 3
# Mean validation score: -0.133 (std: 0.271)
# Parameters: {'min_samples_split': 0.05463463463463463, 'min_samples_leaf': 0.4887187187187187, 'max_depth': 3}
#
# RMSE on test data :  430129632.6253545
# Score with test data -0.03391323918971523
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.008 (std: 0.043)
# Parameters: {'min_samples_split': 0.2871271271271271, 'min_samples_leaf': 0.03844844844844845, 'max_depth': 2}
#
# Model with rank: 1
# Mean validation score: 0.008 (std: 0.043)
# Parameters: {'min_samples_split': 0.4754754754754755, 'min_samples_leaf': 0.06689689689689689, 'max_depth': 2}
#
# Model with rank: 1
# Mean validation score: 0.008 (std: 0.043)
# Parameters: {'min_samples_split': 0.3621721721721722, 'min_samples_leaf': 0.013923923923923925, 'max_depth': 2}
#
# RMSE on test data :  63871726.09769703
# Score with test data -0.004783508625526567
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.219 (std: 0.281)
# Parameters: {'min_samples_split': 0.13850850850850852, 'min_samples_leaf': 0.014414414414414415, 'max_depth': 3}
#
# Model with rank: 2
# Mean validation score: 0.217 (std: 0.273)
# Parameters: {'min_samples_split': 0.48479479479479476, 'min_samples_leaf': 0.012942942942942943, 'max_depth': 4}
#
# Model with rank: 3
# Mean validation score: 0.214 (std: 0.158)
# Parameters: {'min_samples_split': 0.07033033033033033, 'min_samples_leaf': 0.10662662662662661, 'max_depth': 5}
#
# RMSE on test data :  166503.1932017668
# Score with test data 0.29635532631788664
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.028 (std: 0.046)
# Parameters: {'min_samples_split': 0.1439039039039039, 'min_samples_leaf': 0.49803803803803803, 'max_depth': 4}
#
# Model with rank: 2
# Mean validation score: -0.031 (std: 0.045)
# Parameters: {'min_samples_split': 0.45879879879879876, 'min_samples_leaf': 0.499019019019019, 'max_depth': 1}
#
# Model with rank: 3
# Mean validation score: -0.035 (std: 0.064)
# Parameters: {'min_samples_split': 0.05022022022022022, 'min_samples_leaf': 0.4484984984984985, 'max_depth': 2}
#
# RMSE on test data :  49.387022837370246
# Score with test data -0.36277656836010586
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.003 (std: 0.039)
# Parameters: {'min_samples_split': 0.015885885885885888, 'min_samples_leaf': 0.18706706706706705, 'max_depth': 1}
#
# Model with rank: 1
# Mean validation score: 0.003 (std: 0.039)
# Parameters: {'min_samples_split': 0.4867567567567567, 'min_samples_leaf': 0.3136136136136136, 'max_depth': 2}
#
# Model with rank: 1
# Mean validation score: 0.003 (std: 0.039)
# Parameters: {'min_samples_split': 0.3827727727727728, 'min_samples_leaf': 0.268978978978979, 'max_depth': 1}
#
# RMSE on test data :  37914.01592778939
# Score with test data 0.013441583318703931
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.007 (std: 0.044)
# Parameters: {'min_samples_split': 0.3361761761761762, 'min_samples_leaf': 0.3621721721721722, 'max_depth': 3}
#
# Model with rank: 1
# Mean validation score: 0.007 (std: 0.044)
# Parameters: {'min_samples_split': 0.06689689689689689, 'min_samples_leaf': 0.07768768768768768, 'max_depth': 1}
#
# Model with rank: 1
# Mean validation score: 0.007 (std: 0.044)
# Parameters: {'min_samples_split': 0.33323323323323323, 'min_samples_leaf': 0.41906906906906904, 'max_depth': 2}
#
# RMSE on test data :  354.55613699278564
# Score with test data -0.2193363706522269
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.006 (std: 0.041)
# Parameters: {'min_samples_split': 0.26554554554554555, 'min_samples_leaf': 0.3798298298298298, 'max_depth': 3}
#
# Model with rank: 1
# Mean validation score: 0.006 (std: 0.041)
# Parameters: {'min_samples_split': 0.3862062062062062, 'min_samples_leaf': 0.34745745745745743, 'max_depth': 1}
#
# Model with rank: 1
# Mean validation score: 0.006 (std: 0.041)
# Parameters: {'min_samples_split': 0.07474474474474474, 'min_samples_leaf': 0.40435435435435435, 'max_depth': 4}
#
# RMSE on test data :  45227.676360277655
# Score with test data -0.00200994424837897
# new data

# %%
# ---------------> Run for Random Forest regressor
j = 0
for i in y_train.T:
    param = Rf(x_train, i)
    reg_rf = RandomForestRegressor().set_params(**param)
    reg_rf.fit(x_train, i)
    prediction = reg_rf.predict(x_test)

    rmse = mean_squared_error(y_test[:,j], prediction)
    print("RMSE on test data : ", rmse)

    print("Score with test data",reg_rf.score(x_test, y_test[:,j]))
    print('new data\n\n\n\n\n\n')
    j+=1
# Out:
# Model with rank: 1
# Mean validation score: -0.007 (std: 0.045)
# Parameters: {'n_estimators': 33, 'max_depth': 2}
#
# Model with rank: 2
# Mean validation score: -0.009 (std: 0.036)
# Parameters: {'n_estimators': 39, 'max_depth': 2}
#
# Model with rank: 3
# Mean validation score: -0.011 (std: 0.049)
# Parameters: {'n_estimators': 32, 'max_depth': 2}
#
# RMSE on test data :  505254576.43315595
# Score with test data 0.05924584513332509
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.027 (std: 0.066)
# Parameters: {'n_estimators': 32, 'max_depth': 1}
#
# Model with rank: 2
# Mean validation score: -0.030 (std: 0.071)
# Parameters: {'n_estimators': 20, 'max_depth': 1}
#
# Model with rank: 3
# Mean validation score: -0.034 (std: 0.071)
# Parameters: {'n_estimators': 44, 'max_depth': 1}
#
# RMSE on test data :  4347102240.638041
# Score with test data 0.03323388805555694
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.122 (std: 0.159)
# Parameters: {'n_estimators': 6, 'max_depth': 2}
#
# Model with rank: 2
# Mean validation score: 0.122 (std: 0.283)
# Parameters: {'n_estimators': 8, 'max_depth': 2}
#
# Model with rank: 3
# Mean validation score: 0.113 (std: 0.214)
# Parameters: {'n_estimators': 23, 'max_depth': 1}
#
# RMSE on test data :  263743.8809290999
# Score with test data 0.2889597680854329
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.150 (std: 0.239)
# Parameters: {'n_estimators': 15, 'max_depth': 1}
#
# Model with rank: 2
# Mean validation score: 0.150 (std: 0.230)
# Parameters: {'n_estimators': 49, 'max_depth': 1}
#
# Model with rank: 3
# Mean validation score: 0.137 (std: 0.271)
# Parameters: {'n_estimators': 10, 'max_depth': 1}
#
# RMSE on test data :  231779.86588993992
# Score with test data 0.18584915300036442
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.105 (std: 0.154)
# Parameters: {'n_estimators': 22, 'max_depth': 3}
#
# Model with rank: 2
# Mean validation score: 0.101 (std: 0.111)
# Parameters: {'n_estimators': 46, 'max_depth': 2}
#
# Model with rank: 3
# Mean validation score: 0.095 (std: 0.100)
# Parameters: {'n_estimators': 13, 'max_depth': 2}
#
# RMSE on test data :  1474129.1871395102
# Score with test data 0.06729130383558046
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.228 (std: 0.473)
# Parameters: {'n_estimators': 13, 'max_depth': 1}
#
# Model with rank: 2
# Mean validation score: -0.234 (std: 0.424)
# Parameters: {'n_estimators': 24, 'max_depth': 1}
#
# Model with rank: 3
# Mean validation score: -0.267 (std: 0.466)
# Parameters: {'n_estimators': 19, 'max_depth': 1}
#
# RMSE on test data :  499428040.434206
# Score with test data -0.20048753645685083
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.035 (std: 0.030)
# Parameters: {'n_estimators': 46, 'max_depth': 2}
#
# Model with rank: 2
# Mean validation score: 0.034 (std: 0.031)
# Parameters: {'n_estimators': 43, 'max_depth': 2}
#
# Model with rank: 3
# Mean validation score: 0.032 (std: 0.034)
# Parameters: {'n_estimators': 27, 'max_depth': 2}
#
# RMSE on test data :  60255843.68051907
# Score with test data 0.052098921893920846
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.215 (std: 0.262)
# Parameters: {'n_estimators': 8, 'max_depth': 1}
#
# Model with rank: 2
# Mean validation score: 0.210 (std: 0.277)
# Parameters: {'n_estimators': 46, 'max_depth': 1}
#
# Model with rank: 3
# Mean validation score: 0.209 (std: 0.287)
# Parameters: {'n_estimators': 6, 'max_depth': 1}
#
# RMSE on test data :  171904.16109831535
# Score with test data 0.27353076529863196
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.041 (std: 0.077)
# Parameters: {'n_estimators': 6, 'max_depth': 1}
#
# Model with rank: 2
# Mean validation score: -0.046 (std: 0.108)
# Parameters: {'n_estimators': 33, 'max_depth': 1}
#
# Model with rank: 3
# Mean validation score: -0.052 (std: 0.098)
# Parameters: {'n_estimators': 46, 'max_depth': 1}
#
# RMSE on test data :  45.67522357725336
# Score with test data -0.26035385146946344
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.001 (std: 0.025)
# Parameters: {'n_estimators': 47, 'max_depth': 1}
#
# Model with rank: 2
# Mean validation score: -0.002 (std: 0.021)
# Parameters: {'n_estimators': 43, 'max_depth': 1}
#
# Model with rank: 3
# Mean validation score: -0.003 (std: 0.032)
# Parameters: {'n_estimators': 31, 'max_depth': 2}
#
# RMSE on test data :  37503.22279522103
# Score with test data 0.024130807673677812
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.022 (std: 0.040)
# Parameters: {'n_estimators': 4, 'max_depth': 1}
#
# Model with rank: 2
# Mean validation score: 0.009 (std: 0.045)
# Parameters: {'n_estimators': 11, 'max_depth': 1}
#
# Model with rank: 3
# Mean validation score: 0.007 (std: 0.052)
# Parameters: {'n_estimators': 28, 'max_depth': 2}
#
# RMSE on test data :  358.8319190684745
# Score with test data -0.2340410000575739
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.002 (std: 0.026)
# Parameters: {'n_estimators': 10, 'max_depth': 1}
#
# Model with rank: 2
# Mean validation score: 0.002 (std: 0.032)
# Parameters: {'n_estimators': 48, 'max_depth': 1}
#
# Model with rank: 3
# Mean validation score: 0.002 (std: 0.029)
# Parameters: {'n_estimators': 47, 'max_depth': 1}
#
# RMSE on test data :  46247.841942899315
# Score with test data -0.02461150463861439
# new data

# %%
# ---------------> Run for Support Vector regressor
j = 0
for i in y_train.T:
    param = Svr(x_train, i)
    reg_svr = svm.SVR().set_params(**param)
    reg_svr.fit(x_train, i)
    prediction = reg_svr.predict(x_test)

    rmse = mean_squared_error(y_test[:,j], prediction)
    print("RMSE on test data : ", rmse)

    print("Score with test data",reg_svr.score(x_test, y_test[:,j]))
    print('new data\n\n\n\n\n\n')
    j+=1
# Out:
# Model with rank: 1
# Mean validation score: -0.157 (std: 0.036)
# Parameters: {'shrinking': False, 'kernel': 'sigmoid', 'gamma': 'scale'}
#
# Model with rank: 1
# Mean validation score: -0.157 (std: 0.036)
# Parameters: {'shrinking': True, 'kernel': 'sigmoid', 'gamma': 'scale'}
#
# Model with rank: 3
# Mean validation score: -0.157 (std: 0.036)
# Parameters: {'shrinking': False, 'kernel': 'rbf', 'gamma': 'auto'}
#
# RMSE on test data :  614875570.0723639
# Score with test data -0.1448619651406935
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.106 (std: 0.045)
# Parameters: {'shrinking': True, 'kernel': 'poly', 'gamma': 'auto'}
#
# Model with rank: 1
# Mean validation score: -0.106 (std: 0.045)
# Parameters: {'shrinking': False, 'kernel': 'poly', 'gamma': 'auto'}
#
# Model with rank: 3
# Mean validation score: -0.106 (std: 0.046)
# Parameters: {'shrinking': False, 'kernel': 'sigmoid', 'gamma': 'scale'}
#
# Model with rank: 3
# Mean validation score: -0.106 (std: 0.046)
# Parameters: {'shrinking': True, 'kernel': 'sigmoid', 'gamma': 'scale'}
#
# RMSE on test data :  4936951897.027501
# Score with test data -0.09794468271937551
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.016 (std: 0.035)
# Parameters: {'shrinking': False, 'kernel': 'linear', 'gamma': 'scale'}
#
# Model with rank: 2
# Mean validation score: -0.062 (std: 0.025)
# Parameters: {'shrinking': True, 'kernel': 'poly', 'gamma': 'auto'}
#
# Model with rank: 3
# Mean validation score: -0.081 (std: 0.027)
# Parameters: {'shrinking': False, 'kernel': 'sigmoid', 'gamma': 'scale'}
#
# RMSE on test data :  320739.01176504215
# Score with test data 0.13530376323395465
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.051 (std: 0.033)
# Parameters: {'shrinking': True, 'kernel': 'poly', 'gamma': 'auto'}
#
# Model with rank: 1
# Mean validation score: -0.051 (std: 0.033)
# Parameters: {'shrinking': False, 'kernel': 'poly', 'gamma': 'auto'}
#
# Model with rank: 3
# Mean validation score: -0.080 (std: 0.032)
# Parameters: {'shrinking': False, 'kernel': 'sigmoid', 'gamma': 'scale'}
#
# Model with rank: 3
# Mean validation score: -0.080 (std: 0.032)
# Parameters: {'shrinking': True, 'kernel': 'sigmoid', 'gamma': 'scale'}
#
# RMSE on test data :  268542.90354082145
# Score with test data 0.05671516577147706
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.053 (std: 0.045)
# Parameters: {'shrinking': True, 'kernel': 'linear', 'gamma': 'auto'}
#
# Model with rank: 1
# Mean validation score: -0.053 (std: 0.045)
# Parameters: {'shrinking': False, 'kernel': 'linear', 'gamma': 'scale'}
#
# Model with rank: 3
# Mean validation score: -0.072 (std: 0.042)
# Parameters: {'shrinking': False, 'kernel': 'poly', 'gamma': 'scale'}
#
# RMSE on test data :  1492878.6311917242
# Score with test data 0.05542818514265058
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.104 (std: 0.058)
# Parameters: {'shrinking': False, 'kernel': 'rbf', 'gamma': 'auto'}
#
# Model with rank: 2
# Mean validation score: -0.104 (std: 0.058)
# Parameters: {'shrinking': False, 'kernel': 'rbf', 'gamma': 'scale'}
#
# Model with rank: 3
# Mean validation score: -0.104 (std: 0.058)
# Parameters: {'shrinking': True, 'kernel': 'sigmoid', 'gamma': 'scale'}
#
# RMSE on test data :  468309813.612493
# Score with test data -0.12568788479206772
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.170 (std: 0.034)
# Parameters: {'shrinking': True, 'kernel': 'poly', 'gamma': 'scale'}
#
# Model with rank: 2
# Mean validation score: -0.171 (std: 0.033)
# Parameters: {'shrinking': False, 'kernel': 'linear', 'gamma': 'scale'}
#
# Model with rank: 3
# Mean validation score: -0.172 (std: 0.035)
# Parameters: {'shrinking': True, 'kernel': 'rbf', 'gamma': 'auto'}
#
# RMSE on test data :  72508261.33502074
# Score with test data -0.14064719524098823
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.087 (std: 0.040)
# Parameters: {'shrinking': True, 'kernel': 'poly', 'gamma': 'scale'}
#
# Model with rank: 2
# Mean validation score: -0.098 (std: 0.042)
# Parameters: {'shrinking': False, 'kernel': 'sigmoid', 'gamma': 'auto'}
#
# Model with rank: 2
# Mean validation score: -0.098 (std: 0.042)
# Parameters: {'shrinking': True, 'kernel': 'sigmoid', 'gamma': 'auto'}
#
# RMSE on test data :  243170.96433098012
# Score with test data -0.027643677910086595
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.062 (std: 0.028)
# Parameters: {'shrinking': True, 'kernel': 'rbf', 'gamma': 'scale'}
#
# Model with rank: 2
# Mean validation score: -0.076 (std: 0.038)
# Parameters: {'shrinking': True, 'kernel': 'linear', 'gamma': 'auto'}
#
# Model with rank: 2
# Mean validation score: -0.076 (std: 0.038)
# Parameters: {'shrinking': True, 'kernel': 'linear', 'gamma': 'scale'}
#
# RMSE on test data :  36.680779184914314
# Score with test data -0.012162781040681692
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.064 (std: 0.045)
# Parameters: {'shrinking': False, 'kernel': 'linear', 'gamma': 'scale'}
#
# Model with rank: 1
# Mean validation score: -0.064 (std: 0.045)
# Parameters: {'shrinking': True, 'kernel': 'linear', 'gamma': 'scale'}
#
# Model with rank: 3
# Mean validation score: -0.077 (std: 0.046)
# Parameters: {'shrinking': False, 'kernel': 'sigmoid', 'gamma': 'auto'}
#
# RMSE on test data :  38707.45303714036
# Score with test data -0.007204397835820497
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.015 (std: 0.078)
# Parameters: {'shrinking': False, 'kernel': 'linear', 'gamma': 'auto'}
#
# Model with rank: 2
# Mean validation score: -0.023 (std: 0.076)
# Parameters: {'shrinking': False, 'kernel': 'rbf', 'gamma': 'scale'}
#
# Model with rank: 3
# Mean validation score: -0.026 (std: 0.042)
# Parameters: {'shrinking': True, 'kernel': 'poly', 'gamma': 'scale'}
#
# RMSE on test data :  250.2906100602354
# Score with test data 0.13923801554339188
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.077 (std: 0.049)
# Parameters: {'shrinking': True, 'kernel': 'sigmoid', 'gamma': 'scale'}
#
# Model with rank: 2
# Mean validation score: -0.082 (std: 0.049)
# Parameters: {'shrinking': True, 'kernel': 'poly', 'gamma': 'auto'}
#
# Model with rank: 3
# Mean validation score: -0.082 (std: 0.054)
# Parameters: {'shrinking': True, 'kernel': 'rbf', 'gamma': 'scale'}
#
# RMSE on test data :  46948.65709204764
# Score with test data -0.04013792131615279
# new data

# %%
# ---------------> Run for Adaboost regressor
j = 0
for i in y_train.T:
    param = Ada(x_train, i)
    reg_ada = AdaBoostRegressor().set_params(**param)
    reg_ada.fit(x_train, i)
    prediction = reg_ada.predict(x_test)

    rmse = mean_squared_error(y_test[:,j], prediction)
    print("RMSE on test data : ", rmse)

    print("Score with test data",reg_ada.score(x_test, y_test[:,j]))
    print('new data\n\n\n\n\n\n')
    j+=1
# Out:
# Model with rank: 1
# Mean validation score: -0.075 (std: 0.155)
# Parameters: {'n_estimators': 3, 'loss': 'exponential'}
#
# Model with rank: 2
# Mean validation score: -0.292 (std: 0.236)
# Parameters: {'n_estimators': 10, 'loss': 'exponential'}
#
# Model with rank: 3
# Mean validation score: -0.321 (std: 0.344)
# Parameters: {'n_estimators': 11, 'loss': 'exponential'}
#
# RMSE on test data :  574229304.267181
# Score with test data -0.06918102088090428
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.238 (std: 0.353)
# Parameters: {'n_estimators': 3, 'loss': 'exponential'}
#
# Model with rank: 2
# Mean validation score: -0.292 (std: 0.267)
# Parameters: {'n_estimators': 22, 'loss': 'square'}
#
# Model with rank: 3
# Mean validation score: -0.297 (std: 0.196)
# Parameters: {'n_estimators': 60, 'loss': 'square'}
#
# RMSE on test data :  4442767629.093121
# Score with test data 0.01195855324061168
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.003 (std: 0.317)
# Parameters: {'n_estimators': 9, 'loss': 'linear'}
#
# Model with rank: 2
# Mean validation score: -0.085 (std: 0.303)
# Parameters: {'n_estimators': 5, 'loss': 'square'}
#
# Model with rank: 3
# Mean validation score: -0.146 (std: 0.383)
# Parameters: {'n_estimators': 69, 'loss': 'square'}
#
# RMSE on test data :  435252.5424738208
# Score with test data -0.1734189534626056
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.087 (std: 0.509)
# Parameters: {'n_estimators': 8, 'loss': 'linear'}
#
# Model with rank: 2
# Mean validation score: -0.143 (std: 0.391)
# Parameters: {'n_estimators': 13, 'loss': 'exponential'}
#
# Model with rank: 3
# Mean validation score: -0.221 (std: 0.576)
# Parameters: {'n_estimators': 22, 'loss': 'linear'}
#
# RMSE on test data :  292426.25209884887
# Score with test data -0.02717757608962468
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.006 (std: 0.173)
# Parameters: {'n_estimators': 2, 'loss': 'exponential'}
#
# Model with rank: 2
# Mean validation score: -0.026 (std: 0.128)
# Parameters: {'n_estimators': 4, 'loss': 'exponential'}
#
# Model with rank: 3
# Mean validation score: -0.257 (std: 0.326)
# Parameters: {'n_estimators': 1, 'loss': 'square'}
#
# RMSE on test data :  2294495.723473335
# Score with test data -0.4517697181943894
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.148 (std: 0.427)
# Parameters: {'n_estimators': 14, 'loss': 'exponential'}
#
# Model with rank: 2
# Mean validation score: -0.283 (std: 0.295)
# Parameters: {'n_estimators': 7, 'loss': 'square'}
#
# Model with rank: 3
# Mean validation score: -0.571 (std: 1.386)
# Parameters: {'n_estimators': 7, 'loss': 'exponential'}
#
# RMSE on test data :  538215161.9723599
# Score with test data -0.2937211000771638
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.170 (std: 0.307)
# Parameters: {'n_estimators': 6, 'loss': 'exponential'}
#
# Model with rank: 2
# Mean validation score: -0.175 (std: 0.120)
# Parameters: {'n_estimators': 4, 'loss': 'square'}
#
# Model with rank: 3
# Mean validation score: -0.244 (std: 0.317)
# Parameters: {'n_estimators': 7, 'loss': 'linear'}
#
# RMSE on test data :  61567694.58469055
# Score with test data 0.031461838244876916
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.029 (std: 0.321)
# Parameters: {'n_estimators': 5, 'loss': 'exponential'}
#
# Model with rank: 2
# Mean validation score: -0.007 (std: 0.274)
# Parameters: {'n_estimators': 8, 'loss': 'square'}
#
# Model with rank: 3
# Mean validation score: -0.016 (std: 0.306)
# Parameters: {'n_estimators': 11, 'loss': 'exponential'}
#
# RMSE on test data :  207978.17940420168
# Score with test data 0.12108149179737972
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.058 (std: 0.018)
# Parameters: {'n_estimators': 6, 'loss': 'square'}
#
# Model with rank: 2
# Mean validation score: -0.284 (std: 0.319)
# Parameters: {'n_estimators': 1, 'loss': 'exponential'}
#
# Model with rank: 3
# Mean validation score: -0.306 (std: 0.285)
# Parameters: {'n_estimators': 9, 'loss': 'square'}
#
# RMSE on test data :  36.558229093308675
# Score with test data -0.008781155996375967
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.117 (std: 0.169)
# Parameters: {'n_estimators': 4, 'loss': 'linear'}
#
# Model with rank: 2
# Mean validation score: -0.188 (std: 0.190)
# Parameters: {'n_estimators': 6, 'loss': 'exponential'}
#
# Model with rank: 3
# Mean validation score: -0.194 (std: 0.239)
# Parameters: {'n_estimators': 32, 'loss': 'square'}
#
# RMSE on test data :  40059.73991827078
# Score with test data -0.04239217659520711
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.023 (std: 0.064)
# Parameters: {'n_estimators': 6, 'loss': 'square'}
#
# Model with rank: 2
# Mean validation score: -0.036 (std: 0.111)
# Parameters: {'n_estimators': 7, 'loss': 'linear'}
#
# Model with rank: 3
# Mean validation score: -0.132 (std: 0.180)
# Parameters: {'n_estimators': 15, 'loss': 'exponential'}
#
# RMSE on test data :  297.49174683268615
# Score with test data -0.023089065552797328
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.118 (std: 0.062)
# Parameters: {'n_estimators': 8, 'loss': 'square'}
#
# Model with rank: 2
# Mean validation score: -0.325 (std: 0.287)
# Parameters: {'n_estimators': 9, 'loss': 'linear'}
#
# Model with rank: 3
# Mean validation score: -0.399 (std: 0.390)
# Parameters: {'n_estimators': 12, 'loss': 'linear'}
#
# RMSE on test data :  41777.708505748444
# Score with test data 0.0744233898463974
# new data

# %%
# ---------------> Run for Linear regressor
j = 0
for i in y_train.T:
    param = LR(x_train, i)
    reg_lr = LinearRegression().set_params(**param)
    reg_lr.fit(x_train, i)
    prediction = reg_lr.predict(x_test)

    rmse = mean_squared_error(y_test[:,j], prediction)
    print("RMSE on test data : ", rmse)

    print("Score with test data",reg_lr.score(x_test, y_test[:,j]))
    print('new data\n\n\n\n\n\n')
    j+=1
# Out:
# Model with rank: 1
# Mean validation score: 0.006 (std: 0.057)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: 0.006 (std: 0.057)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: 0.006 (std: 0.057)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: 0.006 (std: 0.057)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
#
# RMSE on test data :  503213534.22277963
# Score with test data 0.0630461450795915
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.028 (std: 0.090)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: -0.028 (std: 0.090)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: -0.028 (std: 0.090)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: -0.028 (std: 0.090)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# RMSE on test data :  4333493929.970295
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# Score with test data 0.03626028423078398
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.119 (std: 0.204)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: 0.119 (std: 0.204)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: 0.119 (std: 0.204)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: 0.119 (std: 0.204)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# RMSE on test data :  317598.596795071
# Score with test data 0.14377016397352882
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.149 (std: 0.236)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: 0.149 (std: 0.236)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: 0.149 (std: 0.236)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: 0.149 (std: 0.236)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# RMSE on test data :  235099.18398144678
# Score with test data 0.17418970352538388
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.124 (std: 0.082)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: 0.124 (std: 0.082)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: 0.124 (std: 0.082)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: 0.124 (std: 0.082)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
#
# RMSE on test data :  1168145.742326366
# Score with test data 0.26089266682966117
# new data
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# Model with rank: 1
# Mean validation score: -0.179 (std: 0.379)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: -0.179 (std: 0.379)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: -0.179 (std: 0.379)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: -0.179 (std: 0.379)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# RMSE on test data :  444967000.7948783
# Score with test data -0.06957818812980476
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.052 (std: 0.036)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: 0.052 (std: 0.036)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: 0.052 (std: 0.036)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: 0.052 (std: 0.036)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
#
# RMSE on test data :  61686873.25759474
# Score with test data 0.02958700610192144
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.135 (std: 0.270)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: 0.135 (std: 0.270)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: 0.135 (std: 0.270)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: 0.135 (std: 0.270)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# RMSE on test data :  202354.50166858977
# Score with test data 0.14484722751136614
# new data
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# Model with rank: 1
# Mean validation score: -0.069 (std: 0.142)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: -0.069 (std: 0.142)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: -0.069 (std: 0.142)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: -0.069 (std: 0.142)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# RMSE on test data :  50.79056761174663
# Score with test data -0.40150572880095536
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.008 (std: 0.045)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: -0.008 (std: 0.045)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: -0.008 (std: 0.045)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: -0.008 (std: 0.045)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# RMSE on test data :  35516.06786620278
# Score with test data 0.07583845120599364
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.016 (std: 0.082)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: -0.016 (std: 0.082)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: -0.016 (std: 0.082)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: -0.016 (std: 0.082)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
#
# RMSE on test data :  297.7719395890136
# Score with test data -0.02405266252077287
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.005 (std: 0.044)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 1
# Mean validation score: -0.005 (std: 0.044)
# Parameters: {'normalize': True, 'fit_intercept': True, 'copy_X': False}
#
# Model with rank: 3
# Mean validation score: -0.005 (std: 0.044)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': True}
#
# Model with rank: 3
# Mean validation score: -0.005 (std: 0.044)
# Parameters: {'normalize': False, 'fit_intercept': True, 'copy_X': False}
#
# RMSE on test data :  41920.702627271465
# Score with test data 0.0712553842519078
# new data
# /home/sid/miniconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 8 is smaller than n_iter=25. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)

# %%
# ---------------> Run for Gaussian Process regressor
j = 0
for i in y_train.T:
    param = GP(x_train, i)
    reg_gp = GaussianProcessRegressor().set_params(**param)
    reg_gp.fit(x_train, i)
    prediction = reg_gp.predict(x_test)

    rmse = mean_squared_error(y_test[:,j], prediction)
    print("RMSE on test data : ", rmse)

    print("Score with test data",reg_gp.score(x_test, y_test[:,j]))
    print('new data\n\n\n\n\n\n')
    j+=1
# Out:
# Model with rank: 1
# Mean validation score: -14.197 (std: 8.986)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -14.197 (std: 8.986)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -14.243 (std: 9.032)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -14.243 (std: 9.032)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# RMSE on test data :  7020004231.517602
# Score with test data -12.070832914772284
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -8.822 (std: 6.643)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -8.822 (std: 6.643)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -8.837 (std: 6.680)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -8.837 (std: 6.680)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# RMSE on test data :  31797792576.29493
# Score with test data -6.071613823577462
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -11.437 (std: 5.083)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -11.437 (std: 5.083)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -11.471 (std: 5.138)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -11.471 (std: 5.138)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# RMSE on test data :  6970905.905225141
# Score with test data -17.793211558293365
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -11.095 (std: 7.442)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -11.095 (std: 7.442)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -11.216 (std: 7.752)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -11.216 (std: 7.752)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# RMSE on test data :  3307133.0421715123
# Score with test data -10.616648223892525
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -12.183 (std: 6.646)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -12.183 (std: 6.646)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -12.212 (std: 6.645)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -12.212 (std: 6.645)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# RMSE on test data :  18480883.866641704
# Score with test data -10.69319571554628
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -35.227 (std: 40.547)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -35.227 (std: 40.547)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -35.304 (std: 40.724)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -35.304 (std: 40.724)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# RMSE on test data :  14247006386.35071
# Score with test data -33.24588171654402
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -19.274 (std: 11.894)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -19.274 (std: 11.894)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -19.362 (std: 12.060)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -19.362 (std: 12.060)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# RMSE on test data :  1493021882.649933
# Score with test data -22.487133624807097
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -14.158 (std: 14.917)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -14.158 (std: 14.917)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -14.374 (std: 15.532)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -14.374 (std: 15.532)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# RMSE on test data :  3508670.898028552
# Score with test data -13.827689136925398
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -73.193 (std: 58.935)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -73.193 (std: 58.935)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -73.272 (std: 59.020)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -73.272 (std: 59.020)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# RMSE on test data :  7840.6361428168575
# Score with test data -215.35309444858873
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -29.804 (std: 20.939)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -29.804 (std: 20.939)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -29.877 (std: 21.021)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -29.877 (std: 21.021)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# RMSE on test data :  1765369.5143208294
# Score with test data -44.9365780776928
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -85.545 (std: 72.349)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -85.545 (std: 72.349)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -85.671 (std: 72.341)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -85.671 (std: 72.341)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# RMSE on test data :  44048.396626907255
# Score with test data -150.48464931858098
# new data
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -32.796 (std: 24.274)
# Parameters: {'normalize_y': False, 'copy_X_train': True}
#
# Model with rank: 1
# Mean validation score: -32.796 (std: 24.274)
# Parameters: {'normalize_y': False, 'copy_X_train': False}
#
# Model with rank: 3
# Mean validation score: -32.873 (std: 24.352)
# Parameters: {'normalize_y': True, 'copy_X_train': True}
#
# Model with rank: 3
# Mean validation score: -32.873 (std: 24.352)
# Parameters: {'normalize_y': True, 'copy_X_train': False}
#
# RMSE on test data :  2391657.749979496
# Score with test data -51.98668960192068
# new data

# %%
# ---------------> Run for Neural Net regressor
j = 0
for i in y_train_nn.T:
    param = NN(x_train, i)
    reg_nn = MLPRegressor().set_params(**param)
    reg_nn.fit(x_train, i)
    prediction = reg_nn.predict(x_test)

    rmse = mean_squared_error(y_test_nn[:,j], prediction)
    print("RMSE on test data : ", rmse)

    print("Score with test data",reg_nn.score(x_test, y_test_nn[:,j]))
    print('\n\n\n\n\n\n')
    j+=1
# Out:
# Model with rank: 1
# Mean validation score: 0.010 (std: 0.023)
# Parameters: {'solver': 'adam', 'shuffle': True, 'learning_rate': 'invscaling', 'hidden_layer_sizes': 12, 'alpha': 0.9334986308285207, 'activation': 'logistic'}
#
# Model with rank: 2
# Mean validation score: 0.008 (std: 0.055)
# Parameters: {'solver': 'adam', 'shuffle': True, 'learning_rate': 'invscaling', 'hidden_layer_sizes': 198, 'alpha': 0.1974228227098902, 'activation': 'identity'}
#
# Model with rank: 3
# Mean validation score: 0.006 (std: 0.049)
# Parameters: {'solver': 'sgd', 'shuffle': False, 'learning_rate': 'adaptive', 'hidden_layer_sizes': 73, 'alpha': 0.5407697900045038, 'activation': 'tanh'}
#
# RMSE on test data :  1.000791616181798
# Score with test data 0.045186996019682346
#
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.011 (std: 0.067)
# Parameters: {'solver': 'adam', 'shuffle': True, 'learning_rate': 'constant', 'hidden_layer_sizes': 137, 'alpha': 0.8793447434794246, 'activation': 'logistic'}
#
# Model with rank: 2
# Mean validation score: -0.013 (std: 0.073)
# Parameters: {'solver': 'adam', 'shuffle': True, 'learning_rate': 'invscaling', 'hidden_layer_sizes': 42, 'alpha': 0.6236205788350456, 'activation': 'logistic'}
#
# Model with rank: 3
# Mean validation score: -0.020 (std: 0.084)
# Parameters: {'solver': 'sgd', 'shuffle': True, 'learning_rate': 'constant', 'hidden_layer_sizes': 90, 'alpha': 0.5046042054649352, 'activation': 'tanh'}
#
# RMSE on test data :  0.7101172109914499
# Score with test data 0.031568771874068036
#
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.154 (std: 0.179)
# Parameters: {'solver': 'sgd', 'shuffle': True, 'learning_rate': 'constant', 'hidden_layer_sizes': 26, 'alpha': 0.10638817852336772, 'activation': 'tanh'}
#
# Model with rank: 2
# Mean validation score: 0.138 (std: 0.193)
# Parameters: {'solver': 'sgd', 'shuffle': False, 'learning_rate': 'constant', 'hidden_layer_sizes': 132, 'alpha': 0.15370301026545552, 'activation': 'tanh'}
#
# Model with rank: 3
# Mean validation score: 0.138 (std: 0.192)
# Parameters: {'solver': 'sgd', 'shuffle': False, 'learning_rate': 'constant', 'hidden_layer_sizes': 53, 'alpha': 0.015023989691989465, 'activation': 'tanh'}
#
# RMSE on test data :  0.29590431606774487
# Score with test data 0.1483902483574302
#
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.180 (std: 0.174)
# Parameters: {'solver': 'adam', 'shuffle': False, 'learning_rate': 'invscaling', 'hidden_layer_sizes': 74, 'alpha': 0.7869514902334153, 'activation': 'logistic'}
#
# Model with rank: 2
# Mean validation score: 0.161 (std: 0.217)
# Parameters: {'solver': 'adam', 'shuffle': False, 'learning_rate': 'invscaling', 'hidden_layer_sizes': 150, 'alpha': 0.3437473443381743, 'activation': 'logistic'}
#
# Model with rank: 3
# Mean validation score: 0.155 (std: 0.250)
# Parameters: {'solver': 'adam', 'shuffle': False, 'learning_rate': 'constant', 'hidden_layer_sizes': 163, 'alpha': 0.7789080389910333, 'activation': 'identity'}
#
# RMSE on test data :  0.2389920866407705
# Score with test data 0.27920930859214754
#
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.132 (std: 0.087)
# Parameters: {'solver': 'sgd', 'shuffle': False, 'learning_rate': 'constant', 'hidden_layer_sizes': 182, 'alpha': 0.5107426132520718, 'activation': 'tanh'}
#
# Model with rank: 2
# Mean validation score: 0.132 (std: 0.077)
# Parameters: {'solver': 'adam', 'shuffle': True, 'learning_rate': 'constant', 'hidden_layer_sizes': 27, 'alpha': 0.9220537959829134, 'activation': 'logistic'}
#
# Model with rank: 3
# Mean validation score: 0.131 (std: 0.072)
# Parameters: {'solver': 'adam', 'shuffle': False, 'learning_rate': 'adaptive', 'hidden_layer_sizes': 52, 'alpha': 0.650861463851374, 'activation': 'logistic'}
#
# RMSE on test data :  0.2721118659585818
# Score with test data 0.2415855415177146
#
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.162 (std: 0.369)
# Parameters: {'solver': 'lbfgs', 'shuffle': False, 'learning_rate': 'invscaling', 'hidden_layer_sizes': 124, 'alpha': 0.7246691786292597, 'activation': 'logistic'}
#
# Model with rank: 2
# Mean validation score: -0.163 (std: 0.369)
# Parameters: {'solver': 'lbfgs', 'shuffle': False, 'learning_rate': 'constant', 'hidden_layer_sizes': 127, 'alpha': 0.6330576874185764, 'activation': 'logistic'}
#
# Model with rank: 3
# Mean validation score: -0.174 (std: 0.410)
# Parameters: {'solver': 'adam', 'shuffle': False, 'learning_rate': 'constant', 'hidden_layer_sizes': 101, 'alpha': 0.31133661668124085, 'activation': 'logistic'}
#
# RMSE on test data :  0.10632451263604506
# Score with test data -0.05345389657663868
#
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.059 (std: 0.047)
# Parameters: {'solver': 'sgd', 'shuffle': False, 'learning_rate': 'constant', 'hidden_layer_sizes': 147, 'alpha': 0.6231843419773584, 'activation': 'relu'}
#
# Model with rank: 2
# Mean validation score: 0.058 (std: 0.052)
# Parameters: {'solver': 'sgd', 'shuffle': True, 'learning_rate': 'adaptive', 'hidden_layer_sizes': 191, 'alpha': 0.9285310955585662, 'activation': 'relu'}
#
# Model with rank: 3
# Mean validation score: 0.055 (std: 0.031)
# Parameters: {'solver': 'sgd', 'shuffle': True, 'learning_rate': 'constant', 'hidden_layer_sizes': 106, 'alpha': 0.33359176015173747, 'activation': 'identity'}
#
# RMSE on test data :  1.030399005136432
# Score with test data 0.05870497132066287
#
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.165 (std: 0.286)
# Parameters: {'solver': 'adam', 'shuffle': False, 'learning_rate': 'invscaling', 'hidden_layer_sizes': 53, 'alpha': 0.47198316273812363, 'activation': 'tanh'}
#
# Model with rank: 2
# Mean validation score: 0.159 (std: 0.282)
# Parameters: {'solver': 'adam', 'shuffle': False, 'learning_rate': 'invscaling', 'hidden_layer_sizes': 53, 'alpha': 0.888539461188079, 'activation': 'tanh'}
#
# Model with rank: 3
# Mean validation score: 0.158 (std: 0.260)
# Parameters: {'solver': 'sgd', 'shuffle': False, 'learning_rate': 'constant', 'hidden_layer_sizes': 132, 'alpha': 0.8576763857735129, 'activation': 'tanh'}
#
# RMSE on test data :  0.4594067813892969
# Score with test data 0.22768547147491888
#
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: -0.032 (std: 0.048)
# Parameters: {'solver': 'sgd', 'shuffle': True, 'learning_rate': 'invscaling', 'hidden_layer_sizes': 180, 'alpha': 0.09515046158500343, 'activation': 'logistic'}
#
# Model with rank: 2
# Mean validation score: -0.039 (std: 0.060)
# Parameters: {'solver': 'sgd', 'shuffle': False, 'learning_rate': 'adaptive', 'hidden_layer_sizes': 157, 'alpha': 0.7897035143063966, 'activation': 'logistic'}
#
# Model with rank: 3
# Mean validation score: -0.039 (std: 0.049)
# Parameters: {'solver': 'sgd', 'shuffle': True, 'learning_rate': 'adaptive', 'hidden_layer_sizes': 127, 'alpha': 0.2689086691471114, 'activation': 'logistic'}
#
# RMSE on test data :  0.07276124916151187
# Score with test data -0.04077930453617706
#
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.004 (std: 0.032)
# Parameters: {'solver': 'lbfgs', 'shuffle': False, 'learning_rate': 'constant', 'hidden_layer_sizes': 87, 'alpha': 0.8212568305109048, 'activation': 'logistic'}
#
# Model with rank: 2
# Mean validation score: 0.003 (std: 0.042)
# Parameters: {'solver': 'sgd', 'shuffle': True, 'learning_rate': 'constant', 'hidden_layer_sizes': 170, 'alpha': 0.9149167247752681, 'activation': 'tanh'}
#
# Model with rank: 3
# Mean validation score: 0.002 (std: 0.039)
# Parameters: {'solver': 'adam', 'shuffle': False, 'learning_rate': 'constant', 'hidden_layer_sizes': 164, 'alpha': 0.7877838936542632, 'activation': 'logistic'}
#
# RMSE on test data :  0.30949321765926685
# Score with test data 0.0663126542408875
#
#
#
#
#
#
#
# Model with rank: 1
# Mean validation score: 0.014 (std: 0.084)
# Parameters: {'solver': 'sgd', 'shuffle': False, 'learning_rate': 'adaptive', 'hidden_layer_sizes': 93, 'alpha': 0.4187421315282337, 'activation': 'relu'}
#
# Model with rank: 2
# Mean validation score: 0.003 (std: 0.056)
# Parameters: {'solver': 'adam', 'shuffle': False, 'learning_rate': 'adaptive', 'hidden_layer_sizes': 36, 'alpha': 0.6370055757855487, 'activation': 'logistic'}
#
# Model with rank: 3
# Mean validation score: 0.002 (std: 0.070)
# Parameters: {'solver': 'adam', 'shuffle': True, 'learning_rate': 'adaptive', 'hidden_layer_sizes': 103, 'alpha': 0.9238079757869591, 'activation': 'logistic'}
#
# RMSE on test data :  0.15236892104669383
# Score with test data -0.08848585640930451
# Model with rank: 1
# Mean validation score: 0.011 (std: 0.027)
# Parameters: {'solver': 'adam', 'shuffle': True, 'learning_rate': 'invscaling', 'hidden_layer_sizes': 15, 'alpha': 0.9679528262015413, 'activation': 'logistic'}
#
# Model with rank: 2
# Mean validation score: 0.006 (std: 0.039)
# Parameters: {'solver': 'adam', 'shuffle': False, 'learning_rate': 'constant', 'hidden_layer_sizes': 159, 'alpha': 0.7698670360141316, 'activation': 'logistic'}
#
# Model with rank: 3
# Mean validation score: 0.003 (std: 0.048)
# Parameters: {'solver': 'adam', 'shuffle': False, 'learning_rate': 'invscaling', 'hidden_layer_sizes': 136, 'alpha': 0.5200468122752874, 'activation': 'tanh'}
#
# RMSE on test data :  0.26515294650622623
# Score with test data 0.05071908126896163
